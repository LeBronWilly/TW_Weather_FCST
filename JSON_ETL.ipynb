# %%
# -*- coding: utf-8 -*-
"""
Created on 01/14, 2023
@author: WillyF

"""
# Out:
# '\nCreated on 01/14, 2023\n@author: Willy Fang\n\n'

# %%
import pandas as pd
from pandas.io.json import json_normalize
import numpy as np
from glob import glob
import os
import warnings
warnings.filterwarnings("ignore")
pd.set_option('display.max_columns', 500)
pd.set_option('display.max_rows', 1000)

# %%
data = pd.read_json("https://opendata.cwb.gov.tw/fileapi/v1/opendataapi/F-C0032-001?Authorization=CWB-3D27458E-8F30-4BDF-9589-6DD4A337AA74&downloadType=WEB&format=JSON",orient="index")
data = data.reset_index(drop=True)
data
# Out:
#                          @xmlns                            identifier  \
# 0  urn:cwb:gov:tw:cwbcommon:0.1  e5f09186-fb27-aa31-46c3-2c7cf8102cfd
#
#                sender                       sent  status msgType source  \
# 0  weather@cwb.gov.tw  2023-01-14T10:42:02+08:00  Actual   Issue    MFC
#
#       dataid   scope                                            dataset
# 0  C0032-001  Public  {'datasetInfo': {'datasetDescription': '三十六小時天...

# %%
pd.json_normalize(data,record_path=['dataset'], meta=['sender'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10592/4169581846.py in <module>
# ----> 1 pd.json_normalize(data,record_path=['dataset'], meta=['sender'])
#
# D:\Anaconda3\envs\tensorflow\lib\site-packages\pandas\io\json\_normalize.py in _json_normalize(data, record_path, meta, meta_prefix, record_prefix, errors, sep, max_level)
#     502                 records.extend(recs)
#     503
# --> 504     _recursive_extract(data, record_path, {}, level=0)
#     505
#     506     result = DataFrame(records)
#
# D:\Anaconda3\envs\tensorflow\lib\site-packages\pandas\io\json\_normalize.py in _recursive_extract(data, path, seen_meta, level)
#     475         else:
#     476             for obj in data:
# --> 477                 recs = _pull_records(obj, path[0])
#     478                 recs = [
# ...

# %%
pd.json_normalize(data.to_dict(),record_path=['cwbopendata'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10592/1411891416.py in <module>
# ----> 1 pd.json_normalize(data.to_dict(),record_path=['cwbopendata'])
#
# D:\Anaconda3\envs\tensorflow\lib\site-packages\pandas\io\json\_normalize.py in _json_normalize(data, record_path, meta, meta_prefix, record_prefix, errors, sep, max_level)
#     502                 records.extend(recs)
#     503
# --> 504     _recursive_extract(data, record_path, {}, level=0)
#     505
#     506     result = DataFrame(records)
#
# D:\Anaconda3\envs\tensorflow\lib\site-packages\pandas\io\json\_normalize.py in _recursive_extract(data, path, seen_meta, level)
#     475         else:
#     476             for obj in data:
# --> 477                 recs = _pull_records(obj, path[0])
#     478                 recs = [
# ...

# %%
pd.json_normalize(d['cwbopendata']["dataset"])
# Out:
#                                             location  \
# 0  [{'locationName': '臺北市', 'weatherElement': [{'...
#
#   datasetInfo.datasetDescription      datasetInfo.issueTime  \
# 0                      三十六小時天氣預報  2023-01-14T11:00:00+08:00
#
#           datasetInfo.update
# 0  2023-01-14T10:42:02+08:00

# %%
pd.read_json("https://opendata.cwb.gov.tw/fileapi/v1/opendataapi/F-C0032-001?Authorization=CWB-3D27458E-8F30-4BDF-9589-6DD4A337AA74&downloadType=WEB&format=JSON",orient='records')
# Out:
#                                                   cwbopendata
# @xmlns                           urn:cwb:gov:tw:cwbcommon:0.1
# dataid                                              C0032-001
# dataset     {'datasetInfo': {'datasetDescription': '三十六小時天...
# identifier               e5f09186-fb27-aa31-46c3-2c7cf8102cfd
# msgType                                                 Issue
# scope                                                  Public
# sender                                     weather@cwb.gov.tw
# sent                                2023-01-14T10:42:02+08:00
# source                                                    MFC
# status                                                 Actual

# %%
pd.json_normalize(pd.read_json("https://opendata.cwb.gov.tw/fileapi/v1/opendataapi/F-C0032-001?Authorization=CWB-3D27458E-8F30-4BDF-9589-6DD4A337AA74&downloadType=WEB&format=JSON",orient='records'),"dataset")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10592/1435934028.py in <module>
# ----> 1 pd.json_normalize(pd.read_json("https://opendata.cwb.gov.tw/fileapi/v1/opendataapi/F-C0032-001?Authorization=CWB-3D27458E-8F30-4BDF-9589-6DD4A337AA74&downloadType=WEB&format=JSON",orient='records'),"dataset")
#
# D:\Anaconda3\envs\tensorflow\lib\site-packages\pandas\io\json\_normalize.py in _json_normalize(data, record_path, meta, meta_prefix, record_prefix, errors, sep, max_level)
#     502                 records.extend(recs)
#     503
# --> 504     _recursive_extract(data, record_path, {}, level=0)
#     505
#     506     result = DataFrame(records)
#
# D:\Anaconda3\envs\tensorflow\lib\site-packages\pandas\io\json\_normalize.py in _recursive_extract(data, path, seen_meta, level)
#     475         else:
#     476             for obj in data:
# ...
